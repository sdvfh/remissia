# %%
import pandas as pd
import glob

# %%
# %cd "/content/drive/My Drive/ICFernando/SEER Remodelado"
# Out:
# /content/drive/My Drive/ICFernando/SEER Remodelado

# %%
df = pd.read_csv('./bases/base_seer_customizada/base_seer_customizada.csv')

# %%
df
# Out:
#           CURADO  TEMPO_SOBRE  ...  RADIOTERAPIA  SEQ_TRATAMENTO
# 0              1        261.0  ...             0             0.0
# 1              1        401.0  ...             0             0.0
# 2              1         62.0  ...             0             0.0
# 3              0         46.0  ...             0             0.0
# 4              1         67.0  ...             0             0.0
# ...          ...          ...  ...           ...             ...
# 10450704       0          3.0  ...             0             0.0
# 10450705       0         23.0  ...             1             0.0
# 10450706       0          9.0  ...             0             0.0
# 10450707       0          NaN  ...             0             0.0
# 10450708       0          NaN  ...             0             0.0
#
# [10450709 rows x 45 columns]

# %%
df.drop(columns=['TEMPO_SOBRE', 'SOBRE_COM_CANCER']).to_csv('./bases/curado/curado.csv', index=False)

# %%
df.drop(columns=['CURADO', 'SOBRE_COM_CANCER']).to_csv('./bases/tempo_sobre/tempo_sobre.csv', index=False)

# %%
df.drop(columns=['CURADO', 'TEMPO_SOBRE']).dropna(subset=['SOBRE_COM_CANCER']).to_csv('./bases/sobre_com_cancer/sobre_com_cancer.csv', index=False)
