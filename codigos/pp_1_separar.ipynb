# %%
import os
import time
import glob
import cudf
import pandas as pd
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 100)

# %%
dir_base_origem = 'SEER_1975_2016_CUSTOM_TEXTDATA'
dir_base_destino = 'base_col_sep_quimo'
dic_variaveis = 'dicionario_dados_quimo.txt'

# %%
def ler_dicionario(dic_variaveis):
    '''Funcao que recebe o dicionario em dataframe que retorna:
    1. lista com o nome, a posicao e o tamanho das variaveis;
    2. lista com o nome das variaveis.'''
    lista = []
    for i in range(len(dic_variaveis)):
        
        tam_var = dic_variaveis.iloc[i].to_string()[41:43].strip()
        if tam_var[-1] == '.':
            tam_var = tam_var[0]
        tam_var = int(tam_var)
        
        nome_var = dic_variaveis.iloc[i].to_string()[15:35].strip()
        pos_var = int(dic_variaveis.iloc[i].to_string()[11:14].strip())
        
        lista.append([nome_var, pos_var, tam_var])
    lista_nomes = [nome for nome, pos, tam in lista]
    return lista, lista_nomes

# %%
path_base_origem = '../{0}/incidence'.format(dir_base_origem)
path_base_destino = '../{0}'.format(dir_base_destino)
dic_variaveis = pd.read_csv('../dicionarios/{0}'.format(dic_variaveis), header=None)
lista, lista_nomes = ler_dicionario(dic_variaveis)

# %%
for base_path in glob.iglob('{0}/**/*.TXT'.format(path_base_origem), recursive=True):
    antigo = time.time()
    path_base_destino_temp = os.path.join(dir_base_destino,
                                          base_path.split(sep='/')[-2],
                                          base_path.split(sep='/')[-1][:-4] + '.csv')
    
    if not os.path.exists(os.path.dirname(path_base_destino_temp)):
        os.makedirs(os.path.dirname(path_base_destino_temp))
    df = cudf.read_csv(base_path, header=None)
    
    for nome, pos, tam in lista:
        pos -= 1
        df[nome] = df['0'].str.slice(pos, pos + tam).str.strip()
    df = df.drop('0', axis=1)
    df.to_csv(path_base_destino_temp, index=False)
    
    print('Tempo: {0} s | Salvo em: {1}'.format(round(time.time() - antigo, 2), path_base_destino_temp))
# Out:
# Tempo: 9.75 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/OTHER.csv
# Tempo: 7.31 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/MALEGEN.csv
# Tempo: 2.23 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/LYMYLEUK.csv
# Tempo: 4.39 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/COLRECT.csv
# Tempo: 2.29 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/FEMGEN.csv
# Tempo: 4.23 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/RESPIR.csv
# Tempo: 8.66 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/BREAST.csv
# Tempo: 2.77 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/DIGOTHR.csv
# Tempo: 3.4 s | Salvo em: /home/svf/base_col_sep_quimo/yr1992_2016.sj_lx_rg_ak/URINARY.csv
# Tempo: 13.82 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/OTHER.csv
# Tempo: 12.69 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/MALEGEN.csv
# Tempo: 9.45 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/LYMYLEUK.csv
# Tempo: 12.24 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/COLRECT.csv
# Tempo: 7.62 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/FEMGEN.csv
# Tempo: 13.72 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/RESPIR.csv
# Tempo: 15.37 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/BREAST.csv
# Tempo: 9.11 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/DIGOTHR.csv
# Tempo: 9.59 s | Salvo em: /home/svf/base_col_sep_quimo/yr1975_2016.seer9/URINARY.csv
# Tempo: 13.42 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/OTHER.csv
# Tempo: 11.62 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/MALEGEN.csv
# Tempo: 7.68 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/LYMYLEUK.csv
# Tempo: 11.5 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/COLRECT.csv
# Tempo: 8.37 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/FEMGEN.csv
# Tempo: 12.86 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/RESPIR.csv
# Tempo: 13.38 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/BREAST.csv
# Tempo: 8.71 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/DIGOTHR.csv
# Tempo: 8.52 s | Salvo em: /home/svf/base_col_sep_quimo/yr2000_2016.gc_ky_la_nj_gg/URINARY.csv
# Tempo: 1.21 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/OTHER.csv
# Tempo: 1.12 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/MALEGEN.csv
# Tempo: 0.9 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/LYMYLEUK.csv
# Tempo: 3.41 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/COLRECT.csv
# Tempo: 0.89 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/FEMGEN.csv
# Tempo: 1.17 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/RESPIR.csv
# Tempo: 3.41 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/BREAST.csv
# Tempo: 0.9 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/DIGOTHR.csv
# Tempo: 0.89 s | Salvo em: /home/svf/base_col_sep_quimo/yr2005.la_2nd_half/URINARY.csv
