# %%
import os
import gc
import sys
import glob
import time
import cudf
# import cuml
import cupy
import GPUtil
import pickle
import logging
import numpy as np
import pandas as pd
import xgboost as xgb
import metricas_avaliacao as metric
from bayes_opt.event import Events
from multiprocessing import Process
from bayes_opt.logger import JSONLogger
from bayes_opt import BayesianOptimization
from bayes_opt.util import Colours, load_logs
from scikitplot.helpers import binary_ks_curve
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder, KBinsDiscretizer
from category_encoders.cat_boost import CatBoostEncoder
from sklearn.feature_selection import mutual_info_classif, SelectKBest
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler
# cudf.set_allocator("managed")

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %%
label = 'SRV_TIME_MON'

# %%
gpu = GPUtil.getGPUs()[0]

# %%
def search_model_cat(
            eta, max_depth, gamma, colsample_bytree,
            reg_alpha, reg_lambda, min_child_weight,
            max_delta_step, subsample, colsample_bylevel,
            colsample_bynode, scale_pos_weight,
            perc_nulo_max, tnm_class, encoder_sigma, encoder_a):
    antigo_global = time.time()
    logger.info('Lendo base {0}'.format(tipo))
    db = pd.read_csv('/home/svf/base_col_trat2_quimo_unif/{0}.csv'.format(tipo))
    
    try:
        #perc_nulo_max = 0.2
        logger.info('Retirando colunas com nulos acima de {0} %'.format(str(round(perc_nulo_max * 100, 2))))
        c_apagar = []
        total_linhas = db.shape[0]
        for c in db:
            perc_nulo = db[c].isnull().sum() / total_linhas
            if perc_nulo > perc_nulo_max:
                # logger.info('{0:<20} {1} %'.format(c, round(perc_nulo * 100, 2)))
                #print('{0:<20} {1} %'.format(c, round(perc_nulo * 100, 2)))
                c_apagar.append(c)
        db = db.drop(columns=c_apagar)
        logger.info('Nulos das linhas retiradas')
        db = db.dropna()
        
        if db.shape[0] <= 1e4 or db.shape[0] > 1.5e6:
            return 0

        if round(tnm_class):
            for c in ['value_t', 'value_n', 'value_m', 'value_sg']:
                if c in db.columns:
                    logger.info('Selecionando apenas com classificacao TNM')
                    db = db.loc[db[c] != 888, :]
                    break

        antigo =  time.time()
        encoder = CatBoostEncoder(
            cols=list(db.drop(columns=label).columns),
            drop_invariant=True,
            return_df=True,
            handle_unknown='value',
            handle_missing='value',
            random_state=1,
            sigma=encoder_sigma,
            a=encoder_a)
        db = encoder.fit_transform(db, db[label])
        novo = time.time() - antigo
        logger.info('Utilizando encoder CatBooster: {0} s'.format(round(novo, 2)))
        
        X = db.drop(columns=label).values
        y = db[label].values
        
        enc_scaler = StandardScaler()
        X = enc_scaler.fit_transform(X, y)
        
        logger.info('Utilizando Oversampling')
        sm = RandomOverSampler(random_state=42)
        X, y = sm.fit_resample(X, y)
        
        logger.info('Dividindo base em treino e teste')
        X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                            test_size=0.33, random_state=1,
                                                            stratify=y)

        # logger.info('Memoria GPU: {0} %'.format(round(gpu.memoryUtil * 100, 2)))
        # logger.info('Enviando base para GPU')
        # X_train_gpu, X_test_gpu, y_train_gpu, y_test_gpu = \
        #     cupy.array(X_train), cupy.array(X_test), cupy.array(y_train), cupy.array(y_test), 
        # logger.info('Memoria GPU: {0} %'.format(round(gpu.memoryUtil * 100, 2)))
        
        # max_depth_lim = 1500 / X_train_gpu.shape[1]
        max_depth_lim = 1500 / X_train.shape[1]
        if max_depth > max_depth_lim:
            max_depth = max_depth_lim
        
        params = dict(
                max_depth=int(max_depth),
                learning_rate=eta,
                verbosity=0, 
                objective='binary:logistic', 
                booster='gbtree',
                n_jobs=-1, 
                gamma=gamma, 
                min_child_weight=int(min_child_weight), 
                max_delta_step=int(max_delta_step), 
                subsample=subsample, 
                colsample_bytree=colsample_bytree,
                colsample_bylevel=colsample_bylevel,
                colsample_bynode=colsample_bynode,
                reg_alpha=reg_alpha, 
                reg_lambda=reg_lambda,
                scale_pos_weight=scale_pos_weight, 
                random_state=0,
                tree_method='gpu_hist',
                eval_metric='rmsle')

        score_list = []
        # logger.info('Inserindo base na memoria da GPU')
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=3)
        count = 1
        
        # logger.info('Memoria GPU: {0} %'.format(round(gpu.memoryUtil * 100, 2)))
        # logger.info('Enviando base unificada para GPU')
       
        # dtreino = xgb.DMatrix(X_train_gpu, label=y_train_gpu)
        # dteste = xgb.DMatrix(X_test_gpu, label=y_test_gpu)
        # del X_train_gpu, X_test_gpu, y_train_gpu, y_test_gpu
        dtreino = xgb.DMatrix(X_train, label=y_train)
        dteste = xgb.DMatrix(X_test, label=y_test)
        
        # logger.info('Memoria GPU: {0} %'.format(round(gpu.memoryUtil * 100, 2)))
        logger.info('Shape da base: {0}'.format(X_train.shape))
        
        for train, valid in skf.split(X_train, y_train):
            dtrain = dtreino.slice(train)
            dvalid = dtreino.slice(valid)

            # logger.info('Treinamento {0} | Inicializado'.format(count))
            # logger.info('Memoria GPU: {0} %'.format(round(gpu.memoryUtil * 100, 2)))
            
            antigo = time.time()
            ml = xgb.train(
                params, dtrain, num_boost_round=10000000,
                evals=[
                    (dtrain, 'train'),
                    (dvalid, 'valid')],
                early_stopping_rounds=20,
                verbose_eval=100)
            novo = time.time() - antigo
            
            # logger.info('Memoria GPU antes de apagar: {0} %'.format(round(gpu.memoryUtil * 100, 2)))
            
            pred_scores = ml.predict(dteste, ntree_limit=ml.best_ntree_limit)
            del ml, dtrain, dvalid
            gc.collect()
            
            # logger.info('Memoria GPU depois de apagar: {0} %'.format(round(gpu.memoryUtil * 100, 2)))
            
            # y_valid = y_train[valid]
            # pred = np.around(pred_scores)
            # _, _, _, score_atual, _, _ = binary_ks_curve(y_valid, pred_scores)
            score_atual = roc_auc_score(y_test, pred_scores, average='micro')
            
            logger.info('Treinamento {0} | AUCROC: {1} % | Tempo: {2} s'.format(count,
                                                                                round(score_atual * 100, 2),
                                                                                round(novo, 2)))
            # logger.info('Treinamento {0} | AUCROC: {1} %'.format(count, round(score_atual * 100, 2)))
            count += 1
            #print('KS | {0} %'.format(round(score_atual * 100, 2)))
            
            score_list.append(score_atual)
        
        del dtreino, dteste
        gc.collect()
        novo_global = time.time() - antigo_global
        logger.info('Tempo de treinamento total: {0} min'.format(round(novo_global / 60, 2)))
        return np.mean(score_list)
    except Exception as e:
        logger.exception(e)

# %%
for tipo in [
    'BREAST',
    'COLRECT', 'DIGOTHR', 'FEMGEN', 'LYMYLEUK', 'MALEGEN', 'OTHER', 'RESPIR', 'URINARY']:
    logging.basicConfig(filename='bay_esp.log', level=logging.DEBUG, 
                    format='%(asctime)s | %(levelname)s | %(name)s | %(message)s')
    logger=logging.getLogger(__name__)
    logger.info('########### {0} ##########'.format(tipo))
    try:
        modelo = BayesianOptimization(
            search_model_cat, {
                'eta': (0.001, 1),
                'gamma': (0.001, 1),
                'max_depth': (3, 15), 
                'reg_alpha': (0, 1),
                'reg_lambda': (0, 1),
                'min_child_weight': (1, 30),
                'max_delta_step': (0, 30),
                'subsample': (0.001, 1),
                'colsample_bylevel': (0.001 ,1),
                'colsample_bynode': (0.001, 1),
                'colsample_bytree': (0.001, 1),
                'scale_pos_weight': (0.001, 1),
                'perc_nulo_max': (0.1, 0.8),
                'tnm_class': (0, 1),
                'encoder_sigma': (0, 1),
                'encoder_a': (0.1, 8),
                          })
        if os.path.exists('/home/svf/codigos/bay_esp_{0}.json'.format(tipo)):
            load_logs(modelo, logs=["./bay_esp_{0}.json".format(tipo)])

        logg = JSONLogger(path="./bay_esp_{0}.json".format(tipo))
        modelo.subscribe(Events.OPTIMIZATION_STEP, logg)

        modelo.maximize(init_points=50, n_iter=200, acq='ei')
        with open('/home/svf/codigos/bay_files/bay_file_{0}.pkl', 'wb') as arq:
            pickle.dump(modelo.max, arq)
    except Exception as e:
        logger.exception(e)
# Out:
# [0]	train-rmsle:0.34790	valid-rmsle:0.34795
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25641	valid-rmsle:0.26027
# [200]	train-rmsle:0.24973	valid-rmsle:0.25730
# Stopping. Best iteration:
# [263]	train-rmsle:0.24635	valid-rmsle:0.25624
#
# [0]	train-rmsle:0.34669	valid-rmsle:0.34684
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25504	valid-rmsle:0.25931
# [200]	train-rmsle:0.24881	valid-rmsle:0.25708
# Stopping. Best iteration:
# [269]	train-rmsle:0.24592	valid-rmsle:0.25667
#
# [0]	train-rmsle:0.34602	valid-rmsle:0.34613
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25527	valid-rmsle:0.25989
# [200]	train-rmsle:0.24866	valid-rmsle:0.25692
# Stopping. Best iteration:
# [215]	train-rmsle:0.24804	valid-rmsle:0.25678
#
# [0]	train-rmsle:0.34638	valid-rmsle:0.34647
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25848	valid-rmsle:0.26219
# [200]	train-rmsle:0.25026	valid-rmsle:0.25765
# Stopping. Best iteration:
# [268]	train-rmsle:0.24657	valid-rmsle:0.25652
#
# [0]	train-rmsle:0.34607	valid-rmsle:0.34618
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.26206	valid-rmsle:0.26586
# [200]	train-rmsle:0.25060	valid-rmsle:0.25784
# Stopping. Best iteration:
# [229]	train-rmsle:0.24905	valid-rmsle:0.25723
#
# [0]	train-rmsle:0.34721	valid-rmsle:0.34722
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [13]	train-rmsle:0.28440	valid-rmsle:0.28413
#
# [0]	train-rmsle:0.34766	valid-rmsle:0.34768
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [13]	train-rmsle:0.28647	valid-rmsle:0.28690
#
# [0]	train-rmsle:0.34713	valid-rmsle:0.34714
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [30]	train-rmsle:0.28602	valid-rmsle:0.28658
#
# [0]	train-rmsle:0.34722	valid-rmsle:0.34730
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [26]	train-rmsle:0.28767	valid-rmsle:0.28829
#
# [0]	train-rmsle:0.34740	valid-rmsle:0.34740
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [30]	train-rmsle:0.28728	valid-rmsle:0.28783
#
# [0]	train-rmsle:0.32415	valid-rmsle:0.32443
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [11]	train-rmsle:0.19555	valid-rmsle:0.19673
#
# [0]	train-rmsle:0.32428	valid-rmsle:0.32427
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	train-rmsle:0.19488	valid-rmsle:0.19474
#
# [0]	train-rmsle:0.32414	valid-rmsle:0.32391
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [12]	train-rmsle:0.19519	valid-rmsle:0.19637
#
# [0]	train-rmsle:0.32389	valid-rmsle:0.32403
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [11]	train-rmsle:0.19612	valid-rmsle:0.19599
#
# [0]	train-rmsle:0.32414	valid-rmsle:0.32430
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [7]	train-rmsle:0.19558	valid-rmsle:0.19658
#
# [0]	train-rmsle:0.34495	valid-rmsle:0.34568
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.20973	valid-rmsle:0.25809
# [200]	train-rmsle:0.17804	valid-rmsle:0.25213
# [300]	train-rmsle:0.15413	valid-rmsle:0.24738
# [400]	train-rmsle:0.14095	valid-rmsle:0.24469
# [500]	train-rmsle:0.13234	valid-rmsle:0.24298
# [600]	train-rmsle:0.12363	valid-rmsle:0.24142
# [700]	train-rmsle:0.11769	valid-rmsle:0.24038
# [800]	train-rmsle:0.11399	valid-rmsle:0.23970
# [900]	train-rmsle:0.11173	valid-rmsle:0.23936
# [1000]	train-rmsle:0.11042	valid-rmsle:0.23916
# Stopping. Best iteration:
# [983]	train-rmsle:0.11041	valid-rmsle:0.23913
#
# [0]	train-rmsle:0.34525	valid-rmsle:0.34585
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.21063	valid-rmsle:0.25871
# [200]	train-rmsle:0.17578	valid-rmsle:0.25205
# [300]	train-rmsle:0.15281	valid-rmsle:0.24766
# [400]	train-rmsle:0.13851	valid-rmsle:0.24513
# [500]	train-rmsle:0.12860	valid-rmsle:0.24321
# [600]	train-rmsle:0.12150	valid-rmsle:0.24188
# [700]	train-rmsle:0.11660	valid-rmsle:0.24095
# [800]	train-rmsle:0.11396	valid-rmsle:0.24046
# [900]	train-rmsle:0.11167	valid-rmsle:0.24012
# Stopping. Best iteration:
# [977]	train-rmsle:0.11022	valid-rmsle:0.23994
#
# [0]	train-rmsle:0.34502	valid-rmsle:0.34577
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.20959	valid-rmsle:0.25749
# [200]	train-rmsle:0.17666	valid-rmsle:0.25168
# [300]	train-rmsle:0.15524	valid-rmsle:0.24717
# [400]	train-rmsle:0.13929	valid-rmsle:0.24392
# [500]	train-rmsle:0.13021	valid-rmsle:0.24234
# [600]	train-rmsle:0.12520	valid-rmsle:0.24157
# [700]	train-rmsle:0.12028	valid-rmsle:0.24056
# Stopping. Best iteration:
# [712]	train-rmsle:0.11979	valid-rmsle:0.24044
#
# [0]	train-rmsle:0.34509	valid-rmsle:0.34564
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.21014	valid-rmsle:0.25762
# [200]	train-rmsle:0.17746	valid-rmsle:0.25153
# [300]	train-rmsle:0.15475	valid-rmsle:0.24682
# [400]	train-rmsle:0.13989	valid-rmsle:0.24378
# [500]	train-rmsle:0.13048	valid-rmsle:0.24204
# [600]	train-rmsle:0.12419	valid-rmsle:0.24084
# [700]	train-rmsle:0.11958	valid-rmsle:0.24020
# [800]	train-rmsle:0.11561	valid-rmsle:0.23959
# [900]	train-rmsle:0.11353	valid-rmsle:0.23922
# [1000]	train-rmsle:0.11187	valid-rmsle:0.23877
# [1100]	train-rmsle:0.11086	valid-rmsle:0.23859
# Stopping. Best iteration:
# [1139]	train-rmsle:0.10978	valid-rmsle:0.23838
#
# [0]	train-rmsle:0.34564	valid-rmsle:0.34603
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.21063	valid-rmsle:0.25850
# [200]	train-rmsle:0.17550	valid-rmsle:0.25134
# [300]	train-rmsle:0.15442	valid-rmsle:0.24735
# [400]	train-rmsle:0.14155	valid-rmsle:0.24492
# [500]	train-rmsle:0.13359	valid-rmsle:0.24340
# [600]	train-rmsle:0.12521	valid-rmsle:0.24190
# [700]	train-rmsle:0.12041	valid-rmsle:0.24106
# [800]	train-rmsle:0.11645	valid-rmsle:0.24041
# [900]	train-rmsle:0.11349	valid-rmsle:0.23991
# [1000]	train-rmsle:0.11067	valid-rmsle:0.23940
# Stopping. Best iteration:
# [1046]	train-rmsle:0.10984	valid-rmsle:0.23918
#
# [0]	train-rmsle:0.34968	valid-rmsle:0.34969
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	train-rmsle:0.34309	valid-rmsle:0.34309
#
# [0]	train-rmsle:0.34962	valid-rmsle:0.34962
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [6]	train-rmsle:0.34607	valid-rmsle:0.34607
#
# [0]	train-rmsle:0.34966	valid-rmsle:0.34966
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [6]	train-rmsle:0.34278	valid-rmsle:0.34281
#
# [0]	train-rmsle:0.34963	valid-rmsle:0.34962
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [6]	train-rmsle:0.34460	valid-rmsle:0.34459
#
# [0]	train-rmsle:0.34967	valid-rmsle:0.34967
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [6]	train-rmsle:0.34591	valid-rmsle:0.34590
#
# [0]	train-rmsle:0.30060	valid-rmsle:0.30421
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [9]	train-rmsle:0.26074	valid-rmsle:0.28661
#
# [0]	train-rmsle:0.30109	valid-rmsle:0.30541
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [17]	train-rmsle:0.24502	valid-rmsle:0.28666
#
# [0]	train-rmsle:0.29696	valid-rmsle:0.30112
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	train-rmsle:0.25812	valid-rmsle:0.28530
#
# [0]	train-rmsle:0.29580	valid-rmsle:0.30040
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [4]	train-rmsle:0.26883	valid-rmsle:0.28520
#
# [0]	train-rmsle:0.30327	valid-rmsle:0.30732
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.14832	valid-rmsle:0.27981
# [200]	train-rmsle:0.09394	valid-rmsle:0.27522
# Stopping. Best iteration:
# [217]	train-rmsle:0.08978	valid-rmsle:0.27474
#
# [0]	train-rmsle:0.31735	valid-rmsle:0.31716
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [59]	train-rmsle:0.24597	valid-rmsle:0.24918
#
# [0]	train-rmsle:0.31736	valid-rmsle:0.31776
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.24379	valid-rmsle:0.24912
# Stopping. Best iteration:
# [86]	train-rmsle:0.24438	valid-rmsle:0.24903
#
# [0]	train-rmsle:0.32269	valid-rmsle:0.32286
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [57]	train-rmsle:0.24603	valid-rmsle:0.24952
#
# [0]	train-rmsle:0.31712	valid-rmsle:0.31708
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [60]	train-rmsle:0.24531	valid-rmsle:0.24873
#
# [0]	train-rmsle:0.31706	valid-rmsle:0.31705
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [42]	train-rmsle:0.24688	valid-rmsle:0.24840
#
# [0]	train-rmsle:0.34937	valid-rmsle:0.34942
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [67]	train-rmsle:0.25505	valid-rmsle:0.25777
#
# [0]	train-rmsle:0.34943	valid-rmsle:0.34945
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25462	valid-rmsle:0.25932
# Stopping. Best iteration:
# [105]	train-rmsle:0.25433	valid-rmsle:0.25914
#
# [0]	train-rmsle:0.34927	valid-rmsle:0.34942
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25407	valid-rmsle:0.25898
# Stopping. Best iteration:
# [88]	train-rmsle:0.25448	valid-rmsle:0.25883
#
# [0]	train-rmsle:0.34930	valid-rmsle:0.34935
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [67]	train-rmsle:0.25552	valid-rmsle:0.25859
#
# [0]	train-rmsle:0.34921	valid-rmsle:0.34928
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [55]	train-rmsle:0.25566	valid-rmsle:0.25747
#
# [0]	train-rmsle:0.33550	valid-rmsle:0.33640
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [61]	train-rmsle:0.25116	valid-rmsle:0.27175
#
# [0]	train-rmsle:0.33409	valid-rmsle:0.33480
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [72]	train-rmsle:0.24676	valid-rmsle:0.27066
#
# [0]	train-rmsle:0.33346	valid-rmsle:0.33365
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [65]	train-rmsle:0.24640	valid-rmsle:0.26772
#
# [0]	train-rmsle:0.33529	valid-rmsle:0.33593
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [63]	train-rmsle:0.24894	valid-rmsle:0.26854
#
# [0]	train-rmsle:0.33616	valid-rmsle:0.33670
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.23862	valid-rmsle:0.26857
# Stopping. Best iteration:
# [93]	train-rmsle:0.23992	valid-rmsle:0.26830
#
# [0]	train-rmsle:0.34987	valid-rmsle:0.34998
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25955	valid-rmsle:0.26144
# [200]	train-rmsle:0.25306	valid-rmsle:0.25731
# Stopping. Best iteration:
# [231]	train-rmsle:0.25226	valid-rmsle:0.25718
#
# [0]	train-rmsle:0.35008	valid-rmsle:0.35018
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25665	valid-rmsle:0.25902
# [200]	train-rmsle:0.25242	valid-rmsle:0.25676
# Stopping. Best iteration:
# [237]	train-rmsle:0.25142	valid-rmsle:0.25636
#
# [0]	train-rmsle:0.35015	valid-rmsle:0.35011
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25730	valid-rmsle:0.25963
# Stopping. Best iteration:
# [139]	train-rmsle:0.25404	valid-rmsle:0.25706
#
# [0]	train-rmsle:0.35006	valid-rmsle:0.35016
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25720	valid-rmsle:0.25909
# [200]	train-rmsle:0.25265	valid-rmsle:0.25656
# Stopping. Best iteration:
# [217]	train-rmsle:0.25194	valid-rmsle:0.25631
#
# [0]	train-rmsle:0.35007	valid-rmsle:0.35008
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25606	valid-rmsle:0.25803
# [200]	train-rmsle:0.25187	valid-rmsle:0.25567
# Stopping. Best iteration:
# [215]	train-rmsle:0.25137	valid-rmsle:0.25549
#
# [0]	train-rmsle:0.33171	valid-rmsle:0.33197
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [59]	train-rmsle:0.26117	valid-rmsle:0.26333
#
# [0]	train-rmsle:0.33211	valid-rmsle:0.33220
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [34]	train-rmsle:0.26310	valid-rmsle:0.26433
#
# [0]	train-rmsle:0.33243	valid-rmsle:0.33219
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [43]	train-rmsle:0.26198	valid-rmsle:0.26353
#
# [0]	train-rmsle:0.33527	valid-rmsle:0.33530
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [34]	train-rmsle:0.26008	valid-rmsle:0.26191
#
# [0]	train-rmsle:0.32978	valid-rmsle:0.32989
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [35]	train-rmsle:0.26043	valid-rmsle:0.26150
#
# [0]	train-rmsle:0.32246	valid-rmsle:0.32544
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [22]	train-rmsle:0.23050	valid-rmsle:0.26141
#
# [0]	train-rmsle:0.32215	valid-rmsle:0.32576
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [21]	train-rmsle:0.23253	valid-rmsle:0.26204
#
# [0]	train-rmsle:0.32094	valid-rmsle:0.32365
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [16]	train-rmsle:0.23797	valid-rmsle:0.26064
#
# [0]	train-rmsle:0.32116	valid-rmsle:0.32413
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [16]	train-rmsle:0.23975	valid-rmsle:0.26424
#
# [0]	train-rmsle:0.32278	valid-rmsle:0.32563
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [18]	train-rmsle:0.23516	valid-rmsle:0.26142
#
# [0]	train-rmsle:0.34945	valid-rmsle:0.34969
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.20937	valid-rmsle:0.23003
# [200]	train-rmsle:0.18488	valid-rmsle:0.21943
# [300]	train-rmsle:0.16917	valid-rmsle:0.21626
# [400]	train-rmsle:0.15685	valid-rmsle:0.21493
# [500]	train-rmsle:0.14618	valid-rmsle:0.21412
# [600]	train-rmsle:0.13605	valid-rmsle:0.21355
# [700]	train-rmsle:0.12673	valid-rmsle:0.21311
# [800]	train-rmsle:0.11836	valid-rmsle:0.21286
# Stopping. Best iteration:
# [858]	train-rmsle:0.11402	valid-rmsle:0.21273
#
# [0]	train-rmsle:0.34938	valid-rmsle:0.34964
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.21372	valid-rmsle:0.23426
# [200]	train-rmsle:0.18445	valid-rmsle:0.21940
# [300]	train-rmsle:0.16924	valid-rmsle:0.21613
# [400]	train-rmsle:0.15718	valid-rmsle:0.21485
# [500]	train-rmsle:0.14621	valid-rmsle:0.21403
# [600]	train-rmsle:0.13630	valid-rmsle:0.21343
# [700]	train-rmsle:0.12701	valid-rmsle:0.21295
# [800]	train-rmsle:0.11888	valid-rmsle:0.21267
# [900]	train-rmsle:0.11228	valid-rmsle:0.21241
# [1000]	train-rmsle:0.10593	valid-rmsle:0.21231
# Stopping. Best iteration:
# [1038]	train-rmsle:0.10394	valid-rmsle:0.21226
#
# [0]	train-rmsle:0.34956	valid-rmsle:0.34984
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.20909	valid-rmsle:0.23033
# [200]	train-rmsle:0.18364	valid-rmsle:0.21922
# [300]	train-rmsle:0.16881	valid-rmsle:0.21694
# [400]	train-rmsle:0.15666	valid-rmsle:0.21587
# [500]	train-rmsle:0.14507	valid-rmsle:0.21506
# [600]	train-rmsle:0.13525	valid-rmsle:0.21451
# [700]	train-rmsle:0.12623	valid-rmsle:0.21412
# [800]	train-rmsle:0.11779	valid-rmsle:0.21383
# Stopping. Best iteration:
# [812]	train-rmsle:0.11689	valid-rmsle:0.21382
#
# [0]	train-rmsle:0.34941	valid-rmsle:0.34970
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.21437	valid-rmsle:0.23583
# [200]	train-rmsle:0.18598	valid-rmsle:0.22191
# [300]	train-rmsle:0.17013	valid-rmsle:0.21801
# [400]	train-rmsle:0.15735	valid-rmsle:0.21641
# [500]	train-rmsle:0.14644	valid-rmsle:0.21560
# [600]	train-rmsle:0.13652	valid-rmsle:0.21506
# [700]	train-rmsle:0.12672	valid-rmsle:0.21459
# [800]	train-rmsle:0.11839	valid-rmsle:0.21427
# [900]	train-rmsle:0.11079	valid-rmsle:0.21405
# [1000]	train-rmsle:0.10515	valid-rmsle:0.21400
# Stopping. Best iteration:
# [989]	train-rmsle:0.10571	valid-rmsle:0.21398
#
# [0]	train-rmsle:0.34944	valid-rmsle:0.34974
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.21495	valid-rmsle:0.23626
# [200]	train-rmsle:0.18690	valid-rmsle:0.22247
# [300]	train-rmsle:0.17043	valid-rmsle:0.21812
# [400]	train-rmsle:0.15768	valid-rmsle:0.21630
# [500]	train-rmsle:0.14623	valid-rmsle:0.21550
# [600]	train-rmsle:0.13608	valid-rmsle:0.21487
# [700]	train-rmsle:0.12703	valid-rmsle:0.21444
# [800]	train-rmsle:0.11909	valid-rmsle:0.21419
# Stopping. Best iteration:
# [868]	train-rmsle:0.11397	valid-rmsle:0.21405
#
# [0]	train-rmsle:0.37408	valid-rmsle:0.37412
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [53]	train-rmsle:0.31945	valid-rmsle:0.32737
#
# [0]	train-rmsle:0.37400	valid-rmsle:0.37406
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [76]	train-rmsle:0.31732	valid-rmsle:0.32821
#
# [0]	train-rmsle:0.37447	valid-rmsle:0.37447
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [14]	train-rmsle:0.33790	valid-rmsle:0.33976
#
# [0]	train-rmsle:0.37393	valid-rmsle:0.37396
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [59]	train-rmsle:0.31554	valid-rmsle:0.32394
#
# [0]	train-rmsle:0.37374	valid-rmsle:0.37380
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [12]	train-rmsle:0.32672	valid-rmsle:0.32837
#
# [0]	train-rmsle:0.34153	valid-rmsle:0.34162
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.22888	valid-rmsle:0.23452
# [200]	train-rmsle:0.22195	valid-rmsle:0.23257
# [300]	train-rmsle:0.21665	valid-rmsle:0.23191
# [400]	train-rmsle:0.21125	valid-rmsle:0.23092
# [500]	train-rmsle:0.20621	valid-rmsle:0.23019
# [600]	train-rmsle:0.20129	valid-rmsle:0.22931
# [700]	train-rmsle:0.19663	valid-rmsle:0.22875
# [800]	train-rmsle:0.19219	valid-rmsle:0.22826
# [900]	train-rmsle:0.18761	valid-rmsle:0.22754
# [1000]	train-rmsle:0.18367	valid-rmsle:0.22693
# [1100]	train-rmsle:0.17967	valid-rmsle:0.22634
# [1200]	train-rmsle:0.17579	valid-rmsle:0.22581
# [1300]	train-rmsle:0.17199	valid-rmsle:0.22519
# [1400]	train-rmsle:0.16849	valid-rmsle:0.22464
# [1500]	train-rmsle:0.16496	valid-rmsle:0.22417
# [1600]	train-rmsle:0.16178	valid-rmsle:0.22371
# [1700]	train-rmsle:0.15871	valid-rmsle:0.22327
# [1800]	train-rmsle:0.15567	valid-rmsle:0.22287
# [1900]	train-rmsle:0.15283	valid-rmsle:0.22237
# [2000]	train-rmsle:0.15023	valid-rmsle:0.22202
# [2100]	train-rmsle:0.14753	valid-rmsle:0.22155
# [2200]	train-rmsle:0.14491	valid-rmsle:0.22121
# [2300]	train-rmsle:0.14242	valid-rmsle:0.22081
# [2400]	train-rmsle:0.14005	valid-rmsle:0.22044
# [2500]	train-rmsle:0.13775	valid-rmsle:0.22004
# [2600]	train-rmsle:0.13565	valid-rmsle:0.21971
# [2700]	train-rmsle:0.13375	valid-rmsle:0.21938
# [2800]	train-rmsle:0.13181	valid-rmsle:0.21902
# [2900]	train-rmsle:0.13005	valid-rmsle:0.21880
# [3000]	train-rmsle:0.12824	valid-rmsle:0.21849
# [3100]	train-rmsle:0.12660	valid-rmsle:0.21820
# [3200]	train-rmsle:0.12494	valid-rmsle:0.21794
# [3300]	train-rmsle:0.12331	valid-rmsle:0.21771
# Stopping. Best iteration:
# [3364]	train-rmsle:0.12242	valid-rmsle:0.21762
#
# [0]	train-rmsle:0.34014	valid-rmsle:0.34021
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.22812	valid-rmsle:0.23395
# [200]	train-rmsle:0.22213	valid-rmsle:0.23264
# [300]	train-rmsle:0.21714	valid-rmsle:0.23178
# [400]	train-rmsle:0.21208	valid-rmsle:0.23100
# [500]	train-rmsle:0.20689	valid-rmsle:0.23025
# [600]	train-rmsle:0.20217	valid-rmsle:0.22952
# [700]	train-rmsle:0.19732	valid-rmsle:0.22893
# [800]	train-rmsle:0.19292	valid-rmsle:0.22819
# [900]	train-rmsle:0.18850	valid-rmsle:0.22767
# [1000]	train-rmsle:0.18445	valid-rmsle:0.22708
# [1100]	train-rmsle:0.18069	valid-rmsle:0.22665
# [1200]	train-rmsle:0.17668	valid-rmsle:0.22604
# [1300]	train-rmsle:0.17283	valid-rmsle:0.22544
# [1400]	train-rmsle:0.16914	valid-rmsle:0.22475
# [1500]	train-rmsle:0.16586	valid-rmsle:0.22432
# [1600]	train-rmsle:0.16270	valid-rmsle:0.22384
# [1700]	train-rmsle:0.15947	valid-rmsle:0.22326
# [1800]	train-rmsle:0.15656	valid-rmsle:0.22285
# [1900]	train-rmsle:0.15365	valid-rmsle:0.22236
# [2000]	train-rmsle:0.15060	valid-rmsle:0.22180
# [2100]	train-rmsle:0.14785	valid-rmsle:0.22132
# [2200]	train-rmsle:0.14523	valid-rmsle:0.22087
# [2300]	train-rmsle:0.14289	valid-rmsle:0.22055
# [2400]	train-rmsle:0.14081	valid-rmsle:0.22017
# [2500]	train-rmsle:0.13845	valid-rmsle:0.21981
# [2600]	train-rmsle:0.13636	valid-rmsle:0.21957
# Stopping. Best iteration:
# [2586]	train-rmsle:0.13659	valid-rmsle:0.21956
#
# [0]	train-rmsle:0.34813	valid-rmsle:0.34819
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.22962	valid-rmsle:0.23485
# [200]	train-rmsle:0.22223	valid-rmsle:0.23259
# [300]	train-rmsle:0.21687	valid-rmsle:0.23177
# [400]	train-rmsle:0.21153	valid-rmsle:0.23102
# [500]	train-rmsle:0.20652	valid-rmsle:0.23027
# [600]	train-rmsle:0.20169	valid-rmsle:0.22965
# [700]	train-rmsle:0.19712	valid-rmsle:0.22900
# [800]	train-rmsle:0.19258	valid-rmsle:0.22837
# [900]	train-rmsle:0.18841	valid-rmsle:0.22763
# [1000]	train-rmsle:0.18438	valid-rmsle:0.22698
# [1100]	train-rmsle:0.18030	valid-rmsle:0.22639
# [1200]	train-rmsle:0.17644	valid-rmsle:0.22571
# [1300]	train-rmsle:0.17259	valid-rmsle:0.22508
# [1400]	train-rmsle:0.16911	valid-rmsle:0.22445
# [1500]	train-rmsle:0.16591	valid-rmsle:0.22395
# [1600]	train-rmsle:0.16270	valid-rmsle:0.22350
# [1700]	train-rmsle:0.15956	valid-rmsle:0.22305
# [1800]	train-rmsle:0.15624	valid-rmsle:0.22245
# [1900]	train-rmsle:0.15338	valid-rmsle:0.22203
# [2000]	train-rmsle:0.15075	valid-rmsle:0.22161
# [2100]	train-rmsle:0.14824	valid-rmsle:0.22116
# [2200]	train-rmsle:0.14566	valid-rmsle:0.22070
# [2300]	train-rmsle:0.14327	valid-rmsle:0.22040
# [2400]	train-rmsle:0.14104	valid-rmsle:0.21998
# [2500]	train-rmsle:0.13884	valid-rmsle:0.21962
# [2600]	train-rmsle:0.13674	valid-rmsle:0.21940
# [2700]	train-rmsle:0.13464	valid-rmsle:0.21908
# [2800]	train-rmsle:0.13265	valid-rmsle:0.21879
# [2900]	train-rmsle:0.13065	valid-rmsle:0.21855
# [3000]	train-rmsle:0.12889	valid-rmsle:0.21829
# [3100]	train-rmsle:0.12728	valid-rmsle:0.21798
# [3200]	train-rmsle:0.12561	valid-rmsle:0.21772
# [3300]	train-rmsle:0.12406	valid-rmsle:0.21745
# [3400]	train-rmsle:0.12250	valid-rmsle:0.21722
# Stopping. Best iteration:
# [3394]	train-rmsle:0.12249	valid-rmsle:0.21721
#
# [0]	train-rmsle:0.34855	valid-rmsle:0.34861
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.22881	valid-rmsle:0.23330
# [200]	train-rmsle:0.22242	valid-rmsle:0.23172
# [300]	train-rmsle:0.21710	valid-rmsle:0.23098
# [400]	train-rmsle:0.21165	valid-rmsle:0.23029
# [500]	train-rmsle:0.20658	valid-rmsle:0.22960
# [600]	train-rmsle:0.20184	valid-rmsle:0.22889
# [700]	train-rmsle:0.19722	valid-rmsle:0.22828
# [800]	train-rmsle:0.19278	valid-rmsle:0.22762
# [900]	train-rmsle:0.18874	valid-rmsle:0.22704
# [1000]	train-rmsle:0.18454	valid-rmsle:0.22636
# [1100]	train-rmsle:0.18062	valid-rmsle:0.22572
# [1200]	train-rmsle:0.17652	valid-rmsle:0.22502
# [1300]	train-rmsle:0.17298	valid-rmsle:0.22456
# [1400]	train-rmsle:0.16927	valid-rmsle:0.22397
# [1500]	train-rmsle:0.16612	valid-rmsle:0.22351
# [1600]	train-rmsle:0.16268	valid-rmsle:0.22291
# [1700]	train-rmsle:0.15943	valid-rmsle:0.22241
# [1800]	train-rmsle:0.15633	valid-rmsle:0.22186
# [1900]	train-rmsle:0.15347	valid-rmsle:0.22143
# [2000]	train-rmsle:0.15063	valid-rmsle:0.22093
# [2100]	train-rmsle:0.14812	valid-rmsle:0.22052
# [2200]	train-rmsle:0.14550	valid-rmsle:0.22002
# [2300]	train-rmsle:0.14315	valid-rmsle:0.21971
# [2400]	train-rmsle:0.14069	valid-rmsle:0.21926
# [2500]	train-rmsle:0.13834	valid-rmsle:0.21881
# [2600]	train-rmsle:0.13637	valid-rmsle:0.21852
# [2700]	train-rmsle:0.13417	valid-rmsle:0.21823
# [2800]	train-rmsle:0.13227	valid-rmsle:0.21794
# [2900]	train-rmsle:0.13044	valid-rmsle:0.21762
# [3000]	train-rmsle:0.12879	valid-rmsle:0.21732
# [3100]	train-rmsle:0.12717	valid-rmsle:0.21708
# [3200]	train-rmsle:0.12541	valid-rmsle:0.21672
# [3300]	train-rmsle:0.12402	valid-rmsle:0.21647
# [3400]	train-rmsle:0.12266	valid-rmsle:0.21634
# [3500]	train-rmsle:0.12113	valid-rmsle:0.21614
# [3600]	train-rmsle:0.11963	valid-rmsle:0.21597
# [3700]	train-rmsle:0.11840	valid-rmsle:0.21574
# [3800]	train-rmsle:0.11706	valid-rmsle:0.21560
# Stopping. Best iteration:
# [3793]	train-rmsle:0.11711	valid-rmsle:0.21558
#
# [0]	train-rmsle:0.34536	valid-rmsle:0.34536
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.22873	valid-rmsle:0.23317
# [200]	train-rmsle:0.22276	valid-rmsle:0.23168
# [300]	train-rmsle:0.21726	valid-rmsle:0.23074
# [400]	train-rmsle:0.21214	valid-rmsle:0.22997
# [500]	train-rmsle:0.20707	valid-rmsle:0.22936
# [600]	train-rmsle:0.20241	valid-rmsle:0.22852
# [700]	train-rmsle:0.19787	valid-rmsle:0.22789
# [800]	train-rmsle:0.19346	valid-rmsle:0.22733
# [900]	train-rmsle:0.18913	valid-rmsle:0.22681
# [1000]	train-rmsle:0.18487	valid-rmsle:0.22613
# [1100]	train-rmsle:0.18093	valid-rmsle:0.22545
# [1200]	train-rmsle:0.17689	valid-rmsle:0.22483
# [1300]	train-rmsle:0.17340	valid-rmsle:0.22434
# [1400]	train-rmsle:0.16977	valid-rmsle:0.22374
# [1500]	train-rmsle:0.16630	valid-rmsle:0.22322
# [1600]	train-rmsle:0.16287	valid-rmsle:0.22264
# [1700]	train-rmsle:0.15993	valid-rmsle:0.22219
# [1800]	train-rmsle:0.15696	valid-rmsle:0.22173
# [1900]	train-rmsle:0.15402	valid-rmsle:0.22134
# [2000]	train-rmsle:0.15123	valid-rmsle:0.22085
# [2100]	train-rmsle:0.14851	valid-rmsle:0.22045
# [2200]	train-rmsle:0.14621	valid-rmsle:0.22008
# [2300]	train-rmsle:0.14378	valid-rmsle:0.21973
# [2400]	train-rmsle:0.14132	valid-rmsle:0.21937
# [2500]	train-rmsle:0.13900	valid-rmsle:0.21901
# [2600]	train-rmsle:0.13697	valid-rmsle:0.21865
# [2700]	train-rmsle:0.13483	valid-rmsle:0.21837
# [2800]	train-rmsle:0.13275	valid-rmsle:0.21797
# [2900]	train-rmsle:0.13079	valid-rmsle:0.21763
# [3000]	train-rmsle:0.12902	valid-rmsle:0.21742
# [3100]	train-rmsle:0.12759	valid-rmsle:0.21713
# [3200]	train-rmsle:0.12591	valid-rmsle:0.21687
# [3300]	train-rmsle:0.12442	valid-rmsle:0.21667
# [3400]	train-rmsle:0.12313	valid-rmsle:0.21648
# [3500]	train-rmsle:0.12163	valid-rmsle:0.21626
# Stopping. Best iteration:
# [3571]	train-rmsle:0.12074	valid-rmsle:0.21613
#
# [0]	train-rmsle:0.24374	valid-rmsle:0.24423
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.22074	valid-rmsle:0.22493
#
# [0]	train-rmsle:0.24246	valid-rmsle:0.24343
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.22064	valid-rmsle:0.22435
#
# [0]	train-rmsle:0.24239	valid-rmsle:0.24321
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	train-rmsle:0.22154	valid-rmsle:0.22495
#
# [0]	train-rmsle:0.24254	valid-rmsle:0.24385
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [6]	train-rmsle:0.22046	valid-rmsle:0.22811
#
# [0]	train-rmsle:0.24285	valid-rmsle:0.24511
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [5]	train-rmsle:0.21924	valid-rmsle:0.22738
#
# [0]	train-rmsle:0.28180	valid-rmsle:0.28237
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.13214	valid-rmsle:0.13666
# [200]	train-rmsle:0.12947	valid-rmsle:0.13534
# Stopping. Best iteration:
# [210]	train-rmsle:0.12930	valid-rmsle:0.13529
#
# [0]	train-rmsle:0.28369	valid-rmsle:0.28369
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.13287	valid-rmsle:0.13263
# Stopping. Best iteration:
# [127]	train-rmsle:0.13210	valid-rmsle:0.13236
#
# [0]	train-rmsle:0.28162	valid-rmsle:0.28183
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.13298	valid-rmsle:0.13454
# [200]	train-rmsle:0.13036	valid-rmsle:0.13358
# Stopping. Best iteration:
# [234]	train-rmsle:0.12971	valid-rmsle:0.13347
#
# [0]	train-rmsle:0.28328	valid-rmsle:0.28262
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.13303	valid-rmsle:0.13336
# Stopping. Best iteration:
# [155]	train-rmsle:0.13161	valid-rmsle:0.13264
#
# [0]	train-rmsle:0.28309	valid-rmsle:0.28319
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.13267	valid-rmsle:0.13442
# [200]	train-rmsle:0.13013	valid-rmsle:0.13333
# [300]	train-rmsle:0.12838	valid-rmsle:0.13294
# Stopping. Best iteration:
# [281]	train-rmsle:0.12867	valid-rmsle:0.13289
#
# [0]	train-rmsle:0.32241	valid-rmsle:0.32245
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25669	valid-rmsle:0.26262
# Stopping. Best iteration:
# [145]	train-rmsle:0.25432	valid-rmsle:0.26251
#
# [0]	train-rmsle:0.32243	valid-rmsle:0.32255
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [43]	train-rmsle:0.26053	valid-rmsle:0.26276
#
# [0]	train-rmsle:0.32236	valid-rmsle:0.32253
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25701	valid-rmsle:0.26243
# [200]	train-rmsle:0.25157	valid-rmsle:0.26195
# Stopping. Best iteration:
# [240]	train-rmsle:0.24952	valid-rmsle:0.26180
#
# [0]	train-rmsle:0.32235	valid-rmsle:0.32231
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25713	valid-rmsle:0.26289
# Stopping. Best iteration:
# [102]	train-rmsle:0.25700	valid-rmsle:0.26288
#
# [0]	train-rmsle:0.32240	valid-rmsle:0.32262
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25671	valid-rmsle:0.26244
# Stopping. Best iteration:
# [120]	train-rmsle:0.25571	valid-rmsle:0.26230
#
# [0]	train-rmsle:0.34841	valid-rmsle:0.34840
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	train-rmsle:0.34563	valid-rmsle:0.34567
#
# [0]	train-rmsle:0.34851	valid-rmsle:0.34850
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	train-rmsle:0.34683	valid-rmsle:0.34687
#
# [0]	train-rmsle:0.34812	valid-rmsle:0.34812
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	train-rmsle:0.34803	valid-rmsle:0.34804
#
# [0]	train-rmsle:0.34839	valid-rmsle:0.34841
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	train-rmsle:0.34658	valid-rmsle:0.34667
#
# [0]	train-rmsle:0.34838	valid-rmsle:0.34839
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	train-rmsle:0.34820	valid-rmsle:0.34835
#
# [0]	train-rmsle:0.33409	valid-rmsle:0.33517
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [24]	train-rmsle:0.18115	valid-rmsle:0.18726
#
# [0]	train-rmsle:0.33277	valid-rmsle:0.33243
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [20]	train-rmsle:0.18536	valid-rmsle:0.18888
#
# [0]	train-rmsle:0.33340	valid-rmsle:0.33378
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [66]	train-rmsle:0.18385	valid-rmsle:0.19865
#
# [0]	train-rmsle:0.33392	valid-rmsle:0.33391
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [40]	train-rmsle:0.18568	valid-rmsle:0.19375
#
# [0]	train-rmsle:0.33286	valid-rmsle:0.33306
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [22]	train-rmsle:0.18838	valid-rmsle:0.19423
#
# [0]	train-rmsle:0.34974	valid-rmsle:0.34974
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [13]	train-rmsle:0.33780	valid-rmsle:0.33783
#
# [0]	train-rmsle:0.34974	valid-rmsle:0.34974
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [13]	train-rmsle:0.33769	valid-rmsle:0.33768
#
# [0]	train-rmsle:0.34974	valid-rmsle:0.34974
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [13]	train-rmsle:0.33763	valid-rmsle:0.33769
#
# [0]	train-rmsle:0.34974	valid-rmsle:0.34974
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [13]	train-rmsle:0.33765	valid-rmsle:0.33770
#
# [0]	train-rmsle:0.34974	valid-rmsle:0.34974
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [13]	train-rmsle:0.33768	valid-rmsle:0.33768
#
# [0]	train-rmsle:0.34721	valid-rmsle:0.34728
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25433	valid-rmsle:0.25720
# [200]	train-rmsle:0.25096	valid-rmsle:0.25595
# [300]	train-rmsle:0.24862	valid-rmsle:0.25546
# [400]	train-rmsle:0.24637	valid-rmsle:0.25502
# [500]	train-rmsle:0.24445	valid-rmsle:0.25447
# [600]	train-rmsle:0.24297	valid-rmsle:0.25425
# [700]	train-rmsle:0.24133	valid-rmsle:0.25400
# [800]	train-rmsle:0.23972	valid-rmsle:0.25367
# Stopping. Best iteration:
# [805]	train-rmsle:0.23963	valid-rmsle:0.25361
#
# [0]	train-rmsle:0.34719	valid-rmsle:0.34723
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.26977	valid-rmsle:0.27220
# [200]	train-rmsle:0.25347	valid-rmsle:0.25764
# [300]	train-rmsle:0.24956	valid-rmsle:0.25553
# Stopping. Best iteration:
# [360]	train-rmsle:0.24808	valid-rmsle:0.25509
#
# [0]	train-rmsle:0.34722	valid-rmsle:0.34725
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25532	valid-rmsle:0.25715
# [200]	train-rmsle:0.25170	valid-rmsle:0.25560
# [300]	train-rmsle:0.24935	valid-rmsle:0.25502
# [400]	train-rmsle:0.24708	valid-rmsle:0.25445
# [500]	train-rmsle:0.24488	valid-rmsle:0.25386
# [600]	train-rmsle:0.24309	valid-rmsle:0.25351
# [700]	train-rmsle:0.24144	valid-rmsle:0.25323
# [800]	train-rmsle:0.23980	valid-rmsle:0.25302
# Stopping. Best iteration:
# [823]	train-rmsle:0.23944	valid-rmsle:0.25293
#
# [0]	train-rmsle:0.34720	valid-rmsle:0.34724
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.25505	valid-rmsle:0.25668
# [200]	train-rmsle:0.25152	valid-rmsle:0.25495
# [300]	train-rmsle:0.24916	valid-rmsle:0.25439
# [400]	train-rmsle:0.24713	valid-rmsle:0.25405
# [500]	train-rmsle:0.24521	valid-rmsle:0.25367
# [600]	train-rmsle:0.24317	valid-rmsle:0.25295
# [700]	train-rmsle:0.24151	valid-rmsle:0.25276
# [800]	train-rmsle:0.24003	valid-rmsle:0.25250
# [900]	train-rmsle:0.23862	valid-rmsle:0.25230
# [1000]	train-rmsle:0.23706	valid-rmsle:0.25202
# [1100]	train-rmsle:0.23570	valid-rmsle:0.25181
# [1200]	train-rmsle:0.23433	valid-rmsle:0.25156
# Stopping. Best iteration:
# [1191]	train-rmsle:0.23447	valid-rmsle:0.25155
#
# [0]	train-rmsle:0.34719	valid-rmsle:0.34723
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.26116	valid-rmsle:0.26285
# [200]	train-rmsle:0.25295	valid-rmsle:0.25644
# [300]	train-rmsle:0.24983	valid-rmsle:0.25499
# [400]	train-rmsle:0.24746	valid-rmsle:0.25433
# [500]	train-rmsle:0.24542	valid-rmsle:0.25390
# [600]	train-rmsle:0.24341	valid-rmsle:0.25351
# Stopping. Best iteration:
# [672]	train-rmsle:0.24221	valid-rmsle:0.25325
#
# [0]	train-rmsle:0.29288	valid-rmsle:0.29343
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [7]	train-rmsle:0.23016	valid-rmsle:0.23611
#
# [0]	train-rmsle:0.29429	valid-rmsle:0.29515
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	train-rmsle:0.23033	valid-rmsle:0.23749
#
# [0]	train-rmsle:0.29472	valid-rmsle:0.29585
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [11]	train-rmsle:0.22970	valid-rmsle:0.23863
#
# [0]	train-rmsle:0.29351	valid-rmsle:0.29436
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [10]	train-rmsle:0.22906	valid-rmsle:0.23809
#
# [0]	train-rmsle:0.29177	valid-rmsle:0.29229
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [12]	train-rmsle:0.22795	valid-rmsle:0.23621
#
# [0]	train-rmsle:0.31568	valid-rmsle:0.31571
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [29]	train-rmsle:0.24236	valid-rmsle:0.24679
#
# [0]	train-rmsle:0.31553	valid-rmsle:0.31597
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [35]	train-rmsle:0.24168	valid-rmsle:0.24729
#
# [0]	train-rmsle:0.31555	valid-rmsle:0.31577
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [48]	train-rmsle:0.23977	valid-rmsle:0.24712
#
# [0]	train-rmsle:0.31552	valid-rmsle:0.31574
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [34]	train-rmsle:0.24146	valid-rmsle:0.24685
#
# [0]	train-rmsle:0.31561	valid-rmsle:0.31579
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [33]	train-rmsle:0.24185	valid-rmsle:0.24655
#
# [0]	train-rmsle:0.34656	valid-rmsle:0.34657
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.34656	valid-rmsle:0.34657
#
# [0]	train-rmsle:0.34654	valid-rmsle:0.34656
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.29804	valid-rmsle:0.29944
# [200]	train-rmsle:0.28202	valid-rmsle:0.28476
# Stopping. Best iteration:
# [253]	train-rmsle:0.27710	valid-rmsle:0.28043
#
# [0]	train-rmsle:0.34655	valid-rmsle:0.34656
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.34655	valid-rmsle:0.34656
#
# [0]	train-rmsle:0.34657	valid-rmsle:0.34658
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.34657	valid-rmsle:0.34658
#
# [0]	train-rmsle:0.34655	valid-rmsle:0.34656
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [23]	train-rmsle:0.32490	valid-rmsle:0.32530
#
# [0]	train-rmsle:0.34703	valid-rmsle:0.34694
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27497	valid-rmsle:0.27485
# [200]	train-rmsle:0.24590	valid-rmsle:0.24542
# Stopping. Best iteration:
# [223]	train-rmsle:0.24438	valid-rmsle:0.24385
#
# [0]	train-rmsle:0.34687	valid-rmsle:0.34686
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27514	valid-rmsle:0.27503
# Stopping. Best iteration:
# [179]	train-rmsle:0.24613	valid-rmsle:0.24607
#
# [0]	train-rmsle:0.34680	valid-rmsle:0.34673
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27497	valid-rmsle:0.27490
# Stopping. Best iteration:
# [179]	train-rmsle:0.24580	valid-rmsle:0.24582
#
# [0]	train-rmsle:0.34681	valid-rmsle:0.34688
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27459	valid-rmsle:0.27521
# [200]	train-rmsle:0.24539	valid-rmsle:0.24662
# Stopping. Best iteration:
# [229]	train-rmsle:0.24379	valid-rmsle:0.24509
#
# [0]	train-rmsle:0.34673	valid-rmsle:0.34685
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27476	valid-rmsle:0.27564
# [200]	train-rmsle:0.24576	valid-rmsle:0.24697
# [300]	train-rmsle:0.24145	valid-rmsle:0.24283
# Stopping. Best iteration:
# [292]	train-rmsle:0.24139	valid-rmsle:0.24277
#
# [0]	train-rmsle:0.34943	valid-rmsle:0.34943
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.34647	valid-rmsle:0.34648
#
# [0]	train-rmsle:0.34943	valid-rmsle:0.34943
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.34647	valid-rmsle:0.34647
#
# [0]	train-rmsle:0.34943	valid-rmsle:0.34943
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.34647	valid-rmsle:0.34647
#
# [0]	train-rmsle:0.34943	valid-rmsle:0.34943
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.34648	valid-rmsle:0.34648
#
# [0]	train-rmsle:0.34943	valid-rmsle:0.34943
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.34649	valid-rmsle:0.34648
#
# [0]	train-rmsle:0.34403	valid-rmsle:0.34409
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27874	valid-rmsle:0.27968
# [200]	train-rmsle:0.27607	valid-rmsle:0.27740
# [300]	train-rmsle:0.27438	valid-rmsle:0.27622
# [400]	train-rmsle:0.27338	valid-rmsle:0.27566
# [500]	train-rmsle:0.27236	valid-rmsle:0.27513
# [600]	train-rmsle:0.27144	valid-rmsle:0.27472
# [700]	train-rmsle:0.27063	valid-rmsle:0.27432
# Stopping. Best iteration:
# [715]	train-rmsle:0.27048	valid-rmsle:0.27424
#
# [0]	train-rmsle:0.34409	valid-rmsle:0.34408
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27893	valid-rmsle:0.27968
# [200]	train-rmsle:0.27630	valid-rmsle:0.27746
# [300]	train-rmsle:0.27446	valid-rmsle:0.27605
# [400]	train-rmsle:0.27352	valid-rmsle:0.27554
# [500]	train-rmsle:0.27260	valid-rmsle:0.27509
# [600]	train-rmsle:0.27157	valid-rmsle:0.27449
# [700]	train-rmsle:0.27082	valid-rmsle:0.27422
# [800]	train-rmsle:0.26995	valid-rmsle:0.27381
# Stopping. Best iteration:
# [809]	train-rmsle:0.26984	valid-rmsle:0.27374
#
# [0]	train-rmsle:0.34406	valid-rmsle:0.34407
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.28338	valid-rmsle:0.28435
# [200]	train-rmsle:0.27756	valid-rmsle:0.27920
# [300]	train-rmsle:0.27473	valid-rmsle:0.27697
# [400]	train-rmsle:0.27345	valid-rmsle:0.27621
# [500]	train-rmsle:0.27249	valid-rmsle:0.27582
# [600]	train-rmsle:0.27147	valid-rmsle:0.27529
# [700]	train-rmsle:0.27064	valid-rmsle:0.27498
# Stopping. Best iteration:
# [741]	train-rmsle:0.27029	valid-rmsle:0.27481
#
# [0]	train-rmsle:0.34407	valid-rmsle:0.34408
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27960	valid-rmsle:0.28031
# [200]	train-rmsle:0.27643	valid-rmsle:0.27766
# [300]	train-rmsle:0.27446	valid-rmsle:0.27616
# [400]	train-rmsle:0.27328	valid-rmsle:0.27543
# [500]	train-rmsle:0.27237	valid-rmsle:0.27499
# [600]	train-rmsle:0.27150	valid-rmsle:0.27456
# [700]	train-rmsle:0.27070	valid-rmsle:0.27417
# [800]	train-rmsle:0.27000	valid-rmsle:0.27387
# Stopping. Best iteration:
# [853]	train-rmsle:0.26963	valid-rmsle:0.27373
#
# [0]	train-rmsle:0.34408	valid-rmsle:0.34407
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.27955	valid-rmsle:0.27986
# [200]	train-rmsle:0.27646	valid-rmsle:0.27731
# [300]	train-rmsle:0.27451	valid-rmsle:0.27596
# [400]	train-rmsle:0.27335	valid-rmsle:0.27532
# [500]	train-rmsle:0.27240	valid-rmsle:0.27486
# [600]	train-rmsle:0.27141	valid-rmsle:0.27430
# [700]	train-rmsle:0.27056	valid-rmsle:0.27394
# [800]	train-rmsle:0.26994	valid-rmsle:0.27372
# [900]	train-rmsle:0.26918	valid-rmsle:0.27335
# [1000]	train-rmsle:0.26847	valid-rmsle:0.27300
# [1100]	train-rmsle:0.26777	valid-rmsle:0.27270
# [1200]	train-rmsle:0.26717	valid-rmsle:0.27245
# Stopping. Best iteration:
# [1203]	train-rmsle:0.26715	valid-rmsle:0.27244
#
# [0]	train-rmsle:0.35045	valid-rmsle:0.35071
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.18599	valid-rmsle:0.19224
# Stopping. Best iteration:
# [98]	train-rmsle:0.18616	valid-rmsle:0.19222
#
# [0]	train-rmsle:0.35050	valid-rmsle:0.35064
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.18581	valid-rmsle:0.19390
# Stopping. Best iteration:
# [121]	train-rmsle:0.18282	valid-rmsle:0.19281
#
# [0]	train-rmsle:0.35046	valid-rmsle:0.35068
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.18548	valid-rmsle:0.19352
# Stopping. Best iteration:
# [130]	train-rmsle:0.18177	valid-rmsle:0.19248
#
# [0]	train-rmsle:0.35043	valid-rmsle:0.35063
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.18533	valid-rmsle:0.19529
# Stopping. Best iteration:
# [88]	train-rmsle:0.18676	valid-rmsle:0.19520
#
# [0]	train-rmsle:0.35048	valid-rmsle:0.35067
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.18516	valid-rmsle:0.19550
# Stopping. Best iteration:
# [98]	train-rmsle:0.18529	valid-rmsle:0.19544
#
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
#
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
#
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
#
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
#
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.35741	valid-rmsle:0.35741
#
# [0]	train-rmsle:0.37144	valid-rmsle:0.37157
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [40]	train-rmsle:0.27180	valid-rmsle:0.27674
#
# [0]	train-rmsle:0.37032	valid-rmsle:0.37023
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [43]	train-rmsle:0.27668	valid-rmsle:0.28125
#
# [0]	train-rmsle:0.37033	valid-rmsle:0.37073
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [21]	train-rmsle:0.29647	valid-rmsle:0.29778
#
# [0]	train-rmsle:0.36950	valid-rmsle:0.36961
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [0]	train-rmsle:0.36950	valid-rmsle:0.36961
#
# [0]	train-rmsle:0.37166	valid-rmsle:0.37131
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [8]	train-rmsle:0.36023	valid-rmsle:0.36058
#
# [0]	train-rmsle:0.31289	valid-rmsle:0.31290
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [2]	train-rmsle:0.28647	valid-rmsle:0.28631
#
# [0]	train-rmsle:0.31434	valid-rmsle:0.31492
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [6]	train-rmsle:0.28276	valid-rmsle:0.28291
#
# [0]	train-rmsle:0.31561	valid-rmsle:0.31578
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [1]	train-rmsle:0.28284	valid-rmsle:0.28310
#
# [0]	train-rmsle:0.31441	valid-rmsle:0.31451
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [3]	train-rmsle:0.29861	valid-rmsle:0.29926
#
# [0]	train-rmsle:0.31433	valid-rmsle:0.31414
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# Stopping. Best iteration:
# [4]	train-rmsle:0.27651	valid-rmsle:0.27656
#
# [0]	train-rmsle:0.33972	valid-rmsle:0.33966
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.26606	valid-rmsle:0.26739
# Stopping. Best iteration:
# [153]	train-rmsle:0.25850	valid-rmsle:0.26078
#
# [0]	train-rmsle:0.33966	valid-rmsle:0.33973
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.26614	valid-rmsle:0.26823
# Stopping. Best iteration:
# [83]	train-rmsle:0.26638	valid-rmsle:0.26819
#
# [0]	train-rmsle:0.33969	valid-rmsle:0.33968
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.26603	valid-rmsle:0.26773
# Stopping. Best iteration:
# [169]	train-rmsle:0.25792	valid-rmsle:0.26090
#
# [0]	train-rmsle:0.33965	valid-rmsle:0.33982
# Multiple eval metrics have been passed: 'valid-rmsle' will be used for early stopping.
#
# Will train until valid-rmsle hasn't improved in 20 rounds.
# [100]	train-rmsle:0.26586	valid-rmsle:0.26786
# Stopping. Best iteration:
# [171]	train-rmsle:0.25802	valid-rmsle:0.26092
