# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from base_seer_custom import Base_seer
pd.options.plotting.backend = "plotly"

# %%
import plotly.express as px

# %%
import pyspark
pyspark.__version__
# Out:
# '3.0.0'

# %%
QUERY = '''
SELECT 
TO_DATE(LPAD(CAST(MDXRECMP AS STRING), 2, 0) || '-' || CAST(YEAR_DX AS STRING), 'MM-yyyy')
-- CAST(YEAR_DX AS STRING)
-- MDXRECMP || '-' || YEAR_DX, 'MM-yyyy'
FROM SEER
'''

#s.spark.sql(QUERY).show()

# %%
df = s.spark.sql(QUERY).sample(withReplacement=False, fraction=0.75, seed=1).toPandas()
print(df.shape)

# %%
df = pd.Series(pd.to_datetime(df.iloc[:, 0].values), name='tempo')

# %%
df = pd.DataFrame(index=df)

# %%
df['qtd_exemplo'] = 1

# %%
df_teste = df.groupby(pd.Grouper(freq='M')).count()

# %%
fig = df_teste.plot()

# %%
fig.layout.xaxis.title.text = 'Mês e Ano'

# %%
fig.layout.yaxis.title.text = 'Quantidade Tumor'

# %%
fig.layout.legend.title.text = 'Legenda'

# %%
fig.data[0].hovertemplate = 'Mês e Ano: %{x}<br>Quantidade Tumor: %{y}<extra></extra>'

# %%
fig.data[0].name = 'Quantidade Tumor'

# %%
fig.show()
